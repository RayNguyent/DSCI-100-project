# %%
library(tidyverse)
library(repr)
library(readxl)
# Out:
# ── Attaching packages ─────────────────────────────────────── tidyverse 1.3.0 ──
#
# ✔ ggplot2 3.3.2     ✔ purrr   0.3.4
# ✔ tibble  3.0.3     ✔ dplyr   1.0.2
# ✔ tidyr   1.1.2     ✔ stringr 1.4.0
# ✔ readr   1.3.1     ✔ forcats 0.5.0
#
# Warning message:
# “package ‘ggplot2’ was built under R version 4.0.1”
# Warning message:
# “package ‘tibble’ was built under R version 4.0.2”
# Warning message:
# “package ‘tidyr’ was built under R version 4.0.2”
# Warning message:
# “package ‘dplyr’ was built under R version 4.0.2”
# ── Conflicts ────────────────────────────────────────── tidyverse_conflicts() ──
# ✖ dplyr::filter() masks stats::filter()
# ✖ dplyr::lag()    masks stats::lag()

# %%
df <- read.csv("https://query.data.world/s/5rsuhhhre47qwwe2ydsyntwrtxgtnr", header=TRUE, stringsAsFactors=FALSE)
df_2000_2016 <- df %>% 
    filter(Year <= 2016 & Year >= 2000) %>% 
    filter(Player != "0") %>% 
#     select(Year, Tm, Player, ...)

df_2000_2016
# Out:
#      Year Tm  Player              Age G  MP   PER   TS.   X3PAr FTr   ⋯ D.WORP
# 1    2000 DAL Michael Finley      26  82 3464 19.2  0.522 0.151 0.194 ⋯ -0.8
# 2    2000 SEA Gary Payton         31  82 3425 23.6  0.535 0.312 0.254 ⋯  0.9
# 3    2000 NYK Latrell Sprewell    29  82 3276 15.7  0.515 0.097 0.304 ⋯  2.3
# 4    2000 MIN Kevin Garnett       23  81 3243 23.6  0.545 0.053 0.265 ⋯  7.2
# 5    2000 VAN Shareef Abdur-Rahim 23  82 3223 20.2  0.547 0.075 0.431 ⋯  1.7
# 6    2000 NYK Allan Houston       28  82 3169 16.5  0.569 0.191 0.263 ⋯ -0.8
# 7    2000 LAL Shaquille O'Neal    27  79 3163 30.6  0.578 0.001 0.495 ⋯  8.1
# 8    2000 VAN Mike Bibby          21  82 3155 16.7  0.521 0.206 0.242 ⋯ -3.4
# 9    2000 DET Jerry Stackhouse    25  82 3148 18.9  0.545 0.199 0.524 ⋯ -3.4
# 10   2000 CHH Anthony Mason       33  82 3133 14.4  0.560 0.002 0.637 ⋯  4.7
# 11   2000 TOR Vince Carter        23  82 3126 23.4  0.543 0.139 0.325 ⋯ -0.7
# ...

# %%
all_stars <- read_csv("data/all_stars_2000_2016.csv")
all_stars_2000_2016 <- all_stars %>% 
    filter(Year <= 2016 & Year >= 2000) %>% 
    select(Year, Player)
    

all_stars_2000_2016
# Out:
# Parsed with column specification:
# cols(
#   Year = col_double(),
#   Player = col_character(),
#   Pos = col_character(),
#   HT = col_character(),
#   WT = col_double(),
#   Team = col_character(),
#   `Selection Type` = col_character(),
#   `NBA Draft Status` = col_character(),
#   Nationality = col_character()
# )
#     Year Player
# 1   2016 Stephen Curry
# 2   2016 James Harden
# 3   2016 Kevin Durant
# 4   2016 Kawhi Leonard
# 5   2016 Anthony Davis
# 6   2016 Russell Westbrook
# 7   2016 DeMarcus Cousins
# 8   2016 Klay Thompson
# 9   2016 Draymond Green
# 10  2016 Marc Gasol
# 11  2016 DeAndre Jordan
# 12  2016 Gordon Hayward
# 13  2016 Kyrie Irving
# 14  2016 DeMar DeRozan
# 15  2016 LeBron James
# 16  2016 Giannis Antetokounmpo
# 17  2016 Jimmy Butler
# 18  2016 Isaiah Thomas
# 19  2016 John Wall
# 20  2016 Kevin Love
# 21  2016 Kyle Lowry
# 22  2016 Paul George
# 23  2016 Kemba Walker
# 24  2016 Paul Millsap
# 25  2015 LeBron James
# 26  2015 Dwyane Wade
# ...
